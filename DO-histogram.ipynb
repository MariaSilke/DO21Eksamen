# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.read_csv('inst.csv', sep = ',')
# Out:
#      KKorgnr            Institution_Navn  \
# 0     1639.0    Solstrålen og Smørhullet
# 1     1640.0        Børnehuset Urtehaven
# 2     1643.0         Vuggestuen Sundholm
# 3     1644.0                      Ingolf
# 4     1645.0  Børnehuset Lygtemagerstien
# ..       ...                         ...
# 203   6290.0                  Lyngholmen
# 204   6374.0        Børnehuset i Svinget
# 205   6375.0            Børnehuset Bella
# 206      NaN                         NaN
# 207      NaN                Gennemsnit:
#
#     Andel af pæd personale, der er uddannet 2020 Antal uddannede pædagoger  \
# 0                                            64%                        11
# 1                                            61%                       NaN
# 2                                            41%                       NaN
# 3                                            54%                         6
# 4                                            58%                        10
# ...

# %%
df = pd.read_csv('inst.csv', sep = ',')
df
# Out:
#      KKorgnr            Institution_Navn  \
# 0     1639.0    Solstrålen og Smørhullet
# 1     1640.0        Børnehuset Urtehaven
# 2     1643.0         Vuggestuen Sundholm
# 3     1644.0                      Ingolf
# 4     1645.0  Børnehuset Lygtemagerstien
# ..       ...                         ...
# 203   6290.0                  Lyngholmen
# 204   6374.0        Børnehuset i Svinget
# 205   6375.0            Børnehuset Bella
# 206      NaN                         NaN
# 207      NaN                Gennemsnit:
#
#     Andel af pæd personale, der er uddannet 2020 Antal uddannede pædagoger  \
# 0                                            64%                        11
# 1                                            61%                       NaN
# 2                                            41%                       NaN
# 3                                            54%                         6
# 4                                            58%                        10
# ...

# %%
#df = df.drop([206, 207])
df
# Out:
#      KKorgnr            Institution_Navn  \
# 0     1639.0    Solstrålen og Smørhullet
# 1     1640.0        Børnehuset Urtehaven
# 2     1643.0         Vuggestuen Sundholm
# 3     1644.0                      Ingolf
# 4     1645.0  Børnehuset Lygtemagerstien
# ..       ...                         ...
# 201   6182.0     Børnehuset Den Gule Hat
# 202   6263.0              Enghave Remise
# 203   6290.0                  Lyngholmen
# 204   6374.0        Børnehuset i Svinget
# 205   6375.0            Børnehuset Bella
#
#     Andel af pæd personale, der er uddannet 2020 Antal uddannede pædagoger  \
# 0                                            64%                        11
# 1                                            61%                       NaN
# 2                                            41%                       NaN
# 3                                            54%                         6
# 4                                            58%                        10
# ...

# %%
#ændrer navnet på andelen af pæd. personale..
df.rename(columns = {'Andel af pæd personale, der er uddannet 2020' : 'paedpct', 'Børn pr. voksen (rundet op)' : 'Normering'}, inplace = True)
df
# Out:
#      KKorgnr            Institution_Navn paedpct Antal uddannede pædagoger  \
# 0     1639.0    Solstrålen og Smørhullet     64%                        11
# 1     1640.0        Børnehuset Urtehaven     61%                       NaN
# 2     1643.0         Vuggestuen Sundholm     41%                       NaN
# 3     1644.0                      Ingolf     54%                         6
# 4     1645.0  Børnehuset Lygtemagerstien     58%                        10
# ..       ...                         ...     ...                       ...
# 201   6182.0     Børnehuset Den Gule Hat     62%                       NaN
# 202   6263.0              Enghave Remise     59%                       NaN
# 203   6290.0                  Lyngholmen     22%                         5
# 204   6374.0        Børnehuset i Svinget     55%                       NaN
# 205   6375.0            Børnehuset Bella     64%                       NaN
#
#      Antal pædagogmedhjælpere (inkl. assistenter)  \
# ...

# %%
#jeg dropper de observationer, som ikke har nogen normering, dvs. som vi ikke har data på
df = df.dropna(subset = ['Normering'])

df
# Out:
#      KKorgnr            Institution_Navn paedpct Antal uddannede pædagoger  \
# 0     1639.0    Solstrålen og Smørhullet     64%                        11
# 1     1640.0        Børnehuset Urtehaven     61%                       NaN
# 2     1643.0         Vuggestuen Sundholm     41%                       NaN
# 3     1644.0                      Ingolf     54%                         6
# 4     1645.0  Børnehuset Lygtemagerstien     58%                        10
# ..       ...                         ...     ...                       ...
# 190   5703.0                   Isbjørnen     48%                        24
# 191   5744.0             Børnehuset Jorn     56%                       NaN
# 199   6034.0                     Olympia     60%                         7
# 203   6290.0                  Lyngholmen     22%                         5
# 204   6374.0        Børnehuset i Svinget     55%                       NaN
#
#      Antal pædagogmedhjælpere (inkl. assistenter)  \
# ...

# %%
print(type('paedpct'))
# Out:
# <class 'str'>

# %%
print(df['paedpct'])
# Out:
# 0      64%
# 1      61%
# 2      41%
# 3      54%
# 4      58%
#       ...
# 190    48%
# 191    56%
# 199    60%
# 203    22%
# 204    55%
# Name: paedpct, Length: 99, dtype: object

# %%
#laver string-procenter om til integers, så vi kan bruge dem
df['paedpct'] = df['paedpct'].str.rstrip('%').astype('int')
df
# Out:
#      KKorgnr            Institution_Navn  paedpct Antal uddannede pædagoger  \
# 0     1639.0    Solstrålen og Smørhullet       64                        11
# 1     1640.0        Børnehuset Urtehaven       61                       NaN
# 2     1643.0         Vuggestuen Sundholm       41                       NaN
# 3     1644.0                      Ingolf       54                         6
# 4     1645.0  Børnehuset Lygtemagerstien       58                        10
# ..       ...                         ...      ...                       ...
# 190   5703.0                   Isbjørnen       48                        24
# 191   5744.0             Børnehuset Jorn       56                       NaN
# 199   6034.0                     Olympia       60                         7
# 203   6290.0                  Lyngholmen       22                         5
# 204   6374.0        Børnehuset i Svinget       55                       NaN
#
#      Antal pædagogmedhjælpere (inkl. assistenter)  \
# ...

# %%
fig, ax = plt.subplots(figsize = (17, 10))

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.hist(ppct)
ax.plot()
# Out:
# []

# %%
df['paedpct']
# Out:
# 0      64
# 1      61
# 2      41
# 3      54
# 4      58
#        ..
# 190    48
# 191    56
# 199    60
# 203    22
# 204    55
# Name: paedpct, Length: 99, dtype: int64

# %%
ppct = df['paedpct']

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.hist(ppct)
ax.plot()
# Out:
# []

# %%
props = {
    'title': 'Fordeling af pædagogandele',
    'xlabel': 'Procentdel af inst. som er udd. pædagoger',
    'ylabel': 'Frekvens',
    'xlim': [0, 100]
}


fig, ax = plt.subplots(figsize = (20, 10))
ax.set(**props)
ax.hist(ppct)

ax.plot()
# Out:
# []

# %%
sns.distplot(ppct,hist=True)
# Out:
# <AxesSubplot:xlabel='paedpct', ylabel='Density'>

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax = sns.distplot(ppct,hist=True)
ax.set(xlabel='Procentdel af inst. som er udd. pædagoger')
sns.despine()
plt.axvline(x=66, ymin=0, ymax=1, color = 'red', label = 'målsætning')
plt.text(67.1,0.04,'målsætning',rotation=0)
# Out:
# Text(67.1, 0.04, 'målsætning')
