# %% [markdown]
# # Normeringer
# ### Tabeller og plots over forskellige datasæt

# %%
# Datapakker importeres.

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import seaborn as sns

# %% [markdown]
# ## Datasæt: antal uddannede pædagoger
# ##### Fra danmarks statistik

# %%
# Datasæt med antallet af uddannede pædagoger i Kbh indlæses.

antal_uddannede1 = pd.read_excel ('Antal uddannede pædagoger1.xlsx', sep = ',')
antal_uddannede1

# Vi ændrer dataframe så kolonnen med uddannelsessteder i København er index.
antal_uddannede = antal_uddannede1.set_index('Unnamed: 0')
antal_uddannede

antal_uddannede.index.names = ['Uddannelsessteder i Kbh']

# Vis datasættet
antal_uddannede
# Out:
#                                              2005  2006  2007  2008  2009  \
# Uddannelsessteder i Kbh
# 101562 CVU ØreSund                             74    63    18     0     0
# 151408 CVU Storkøbenhavn                        0    17    13     0     0
# 219416 Københavns Professionshøjskole (UCC)  2220  2219  2214  2176  2207
# 219417 Københavns Professionshøjskole        1514  1288  1278  1733  1720
# 101562 CVU ØreSund                              0     0     0     0     0
# 151408 CVU Storkøbenhavn                        0     0     0     0     0
# 219416 Københavns Professionshøjskole (UCC)  2041  2093  2087  2054  2029
# 219417 Københavns Professionshøjskole         174   184   159   181   175
# 101562 CVU ØreSund                              0     0     0     0     0
# 151408 CVU Storkøbenhavn                        0     0     0     0     0
# 219416 Københavns Professionshøjskole (UCC)  1393  1450  1417  1361  1443
# ...

# %% [markdown]
# ## Datasæt: antal børn i Københavns Kommune
# ##### Fra danmarks statistik

# %%
# Indlæser datasæt med antal børn i Kbh
antal_boern1 = pd.read_excel ('Antal børn i KK.xlsx', sep = ',')

# Vi ændrer dataframe så kolonnen med børnenes alder er index.
antal_boern = antal_boern1.set_index('Unnamed: 0')

antal_boern.index.names = ['Alder']
antal_boern.columns.names = ['Årstal']

# Vis datasættet
antal_boern
# Out:
# Årstal  2015  2016  2017  2018  2019  2020  2021
# Alder
# 0 år    8850  9138  9642  9741  9584  9921  9481
# 1 år    7911  8039  8419  8750  8810  8590  8681
# 2 år    7460  7238  7430  7668  8027  8044  7633
# 3 år    7053  6917  6700  6867  7036  7307  7273
# 4 år    6934  6611  6563  6301  6488  6607  6847
# 5 år    6298  6603  6322  6192  6020  6148  6137
# 6 år    6022  6031  6301  6019  5963  5773  5808

# %% [markdown]
# ## Datasæt: befolkningsfremskrivning for børn i KK
# ##### Fra danmarks statistik

# %%
# Indlæser datasæt med befolkningfremskrivningen af 0-6 årige børn i Københavns Kommune
befolkningsfremskrivning1 = pd.read_excel ('Befolkningsfremskrivning KK 0-6 år.xlsx', sep = ',')

# Vi ændrer dataframe så kolonnen med børnenes alder er index
befolkningsfremskrivning = befolkningsfremskrivning1.set_index('Unnamed: 0')

befolkningsfremskrivning.index.names = ['Alder']
befolkningsfremskrivning.columns.names = ['Årstal']

# Vis datasættet
befolkningsfremskrivning
# Out:
# Årstal  2020  2021   2022   2023   2024   2025   2026   2027   2028   2029  \
# Alder
# 0 år    9921  9892  10075  10282  10519  10817  11169  11496  11723  11846
# 1 år    8590  8980   8949   9115   9299   9512   9780  10096  10390  10593
# 2 år    8044  7863   8204   8175   8325   8490   8684   8927   9214   9481
# 3 år    7307  7374   7215   7518   7489   7625   7776   7951   8173   8434
# 4 år    6607  6878   6935   6791   7066   7037   7164   7304   7467   7674
# 5 år    6148  6266   6522   6574   6440   6694   6667   6786   6917   7068
# 6 år    5773  5872   5981   6227   6273   6150   6385   6358   6469   6593
#
# Årstal  ...   2036   2037   2038   2039   2040   2041   2042   2043   2044  \
# Alder   ...
# 0 år    ...  11893  11868  11833  11782  11718  11641  11559  11475  11399
# 1 år    ...  10758  10743  10721  10688  10643  10584  10514  10439  10363
# 2 år    ...   9820   9811   9797   9776   9746   9703   9650   9586   9518
# ...

# %% [markdown]
# ## Datasæt: løn for pædagogisk personale i DK og fra KK
# ##### Fra BUPL
# - Første tabel er forskellige typer pædagogisk personale i DK
# - Anden tabel er gennemsnitsløn i KK

# %%
# Indlæser datasæt med lønnen for forskellige typer af pædagogisk personale i DK

loen1 = pd.read_excel ('Løn for forskellige typer pædagoger.xlsx', sep = ',')
loen1

# Vi ændrer dataframe så kolonnen med løntyper er index.
loen = loen1.set_index('Unnamed: 0')

loen.index.names = ['Løntype']
loen.columns.names = ['Pædagog udd']

# Vis datasættet
loen
# Out:
# Pædagog udd            Ikke udd personale  Pædagog 0-5 år  Pædagoger  \
# Løntype
# Samlet løn                          32863           36131      36863
# Pensions bidrag                      3624            4589       4660
# Feriegodtgørelse                      559             603        616
# Særydelser                           2010              47        184
# Andre tillæg                          126             114        117
# Garanti tillæg                        139             653        704
# Kvalifikations tillæg                1243            2436       2463
# Funktions tillæg                     1338             800       1225
# Grundløn                            23540           26816      26819
#
# Pædagog udd            Pædagoger 6-18 år  Pædagog særlige stillinger  \
# Løntype
# Samlet løn                         37666                       38337
# Pensions bidrag                     4729                        5053
# ...

# %%
# Indlæser datasæt med gennemsnitslønnen for pædagoger Københavns Kommune

loen_kbh1 = pd.read_excel ('Løn pædagoger kbh.xlsx', sep = ',')
loen_kbh1

# Vi ændrer dataframe så kolonnen med løntyper er index.
loen_kbh = loen_kbh1.set_index('Kommune')

# Vis datasættet
loen_kbh
# Out:
#                 Region  Fultid   Grundløn (%)  Centrale tillæg (%)  \
# Kommune
# København  Hovedstaden     4084            84                    2
#
#            Lokale tillæg (%)  Samlet løn
# Kommune
# København                 14       32659

# %% [markdown]
# ## Finder summen af kolonner i datasæt: antal_boern og antal_uddannede tabeller

# %%
# Finder summen af alle kolonner i datasættet antal_boern og navngiver i alt
sums_boern = antal_boern.sum().rename('Børn i alt')

# Indsætter i 'alt'-rækken i antal_boern dataframe
boern_sum = antal_boern.append(sums_boern)

# Vis datasættet
boern_sum
# Out:
# Årstal       2015   2016   2017   2018   2019   2020   2021
# Alder
# 0 år         8850   9138   9642   9741   9584   9921   9481
# 1 år         7911   8039   8419   8750   8810   8590   8681
# 2 år         7460   7238   7430   7668   8027   8044   7633
# 3 år         7053   6917   6700   6867   7036   7307   7273
# 4 år         6934   6611   6563   6301   6488   6607   6847
# 5 år         6298   6603   6322   6192   6020   6148   6137
# 6 år         6022   6031   6301   6019   5963   5773   5808
# Børn i alt  50528  50577  51377  51538  51928  52390  51860

# %%
# Tager summen af alle kolonner i datasættet antal_uddannede og navngiver 'i alt'
sums_uddannede = antal_uddannede.sum().rename('Uddannede i alt')

# Indsætter 'i alt'-rækken i antal_uddannede dataframe
udd_sum = antal_uddannede.append(sums_uddannede)

# Vis datasættet
udd_sum
# Out:
#                                              2005  2006  2007  2008  2009  \
# Uddannelsessteder i Kbh
# 101562 CVU ØreSund                             74    63    18     0     0
# 151408 CVU Storkøbenhavn                        0    17    13     0     0
# 219416 Københavns Professionshøjskole (UCC)  2220  2219  2214  2176  2207
# 219417 Københavns Professionshøjskole        1514  1288  1278  1733  1720
# 101562 CVU ØreSund                              0     0     0     0     0
# 151408 CVU Storkøbenhavn                        0     0     0     0     0
# 219416 Københavns Professionshøjskole (UCC)  2041  2093  2087  2054  2029
# 219417 Københavns Professionshøjskole         174   184   159   181   175
# 101562 CVU ØreSund                              0     0     0     0     0
# 151408 CVU Storkøbenhavn                        0     0     0     0     0
# 219416 Københavns Professionshøjskole (UCC)  1393  1450  1417  1361  1443
# ...

# %% [markdown]
# ## Concat af antal_børn og antal_uddannede i alt
# Benytter 'i alt' rækkerne og de årstal, som de to tabeller har til fælles til at kombinere dem i én tabel

# %%
# Concat bruges til at sammenflette boern_sum og udd_sum ud fra de kolonner de to tabeller deler
concat_boern_udd = pd.concat([boern_sum, udd_sum], join='inner', axis=0, sort=False)

# Bytter om på rækker og kolonner for at få en pænere tabel
concat_boern_udd2 = concat_boern_udd.T

# Vis datasættet
concat_boern_udd2
# Out:
#       0 år  1 år  2 år  3 år  4 år  5 år  6 år  Børn i alt  \
# 2015  8850  7911  7460  7053  6934  6298  6022       50528
# 2016  9138  8039  7238  6917  6611  6603  6031       50577
# 2017  9642  8419  7430  6700  6563  6322  6301       51377
# 2018  9741  8750  7668  6867  6301  6192  6019       51538
# 2019  9584  8810  8027  7036  6488  6020  5963       51928
# 2020  9921  8590  8044  7307  6607  6148  5773       52390
#
#       101562 CVU ØreSund  151408 CVU Storkøbenhavn  ...  \
# 2015                   0                         0  ...
# 2016                   0                         0  ...
# 2017                   0                         0  ...
# 2018                   0                         0  ...
# 2019                   0                         0  ...
# 2020                   0                         0  ...
#
#       219417 Københavns Professionshøjskole  101562 CVU ØreSund  \
# 2015                                   2196                   0
# ...

# %% [markdown]
# ### Sammenflettet tabel kun med sumværdierne fra antal børn og antal uddannede pædagoger

# %%
# Laver en tabel med årstal og summen af børn for hver årstal og uddannede pædagoger for hvert årstal (2015-2020)
ialt_boern_udd = concat_boern_udd2[['Børn i alt', 'Uddannede i alt']]

# Reset af index, så Årstal er kolonnenavn
ialt_boern_udd1 = ialt_boern_udd.reset_index()
ialt_boern_udd1.rename(columns={'index': 'Årstal'}, inplace=True)

# Vis datasættet
ialt_boern_udd1
# Out:
#   Årstal  Børn i alt  Uddannede i alt
# 0   2015       50528             7718
# 1   2016       50577             8187
# 2   2017       51377             7794
# 3   2018       51538             7645
# 4   2019       51928             7518
# 5   2020       52390             7445

# %% [markdown]
# # Plot for udviklingen af antal børn og antal pædagoger i KK 2015-2020

# %%
#Plot for udviklingen i antal børn i KK
fig, ax = plt.subplots(figsize=(10, 5))
x1 = ialt_boern_udd1['Årstal']
y1 = ialt_boern_udd1['Børn i alt']
ax.scatter(x1, y1)
ax.plot(x1, y1)
ax.set(xlabel='Årstal', ylabel='Antal børn 0-6 år i Københavns Kommune', title='Udvikling i antal børn 2015-2020 i Københavns Kommune')
plt.ylim((50000,53000))

# Plot for udviklingen i antal uddannede pædagoger i KK
fig, ax = plt.subplots(figsize=(10, 5))
x2 = ialt_boern_udd1['Årstal']
y2 = ialt_boern_udd1['Uddannede i alt']
ax.plot(x2, y2)
ax.scatter(x2, y2)
ax.set(xlabel='Årstal', ylabel='Antal uddannede pædagoger i Københavns Kommune', title='Udvikling i antal uddannede pædagoger 2015-2020 i Københavns Kommune')
# Out:
# [Text(0, 0.5, 'Antal uddannede pædagoger i Københavns Kommune'),
#  Text(0.5, 0, 'Årstal'),
#  Text(0.5, 1.0, 'Udvikling i antal uddannede pædagoger 2015-2020 i Københavns Kommune')]

# %% [markdown]
# ## Befolkningfremskrivning børn 0-6 år i Københavns Kommune - pæn og ordnet tabel

# %%
# Tager summen af alle kolonner og navngiver i alt
sums_befolkningsfremskrivning = befolkningsfremskrivning.sum().rename('Børn i alt')

# Indsætter 'i alt'-rækken i befolkningsfremskrivning dataframe
befolkningsfremskrivning_sum = befolkningsfremskrivning.append(sums_befolkningsfremskrivning)
befolkningsfremskrivning_sum 

# Bytter rundt på rækker og kolonner
befolkningsfremskrivning_T = befolkningsfremskrivning_sum.T

# Reset af index, så Årstal er kolonnenavn
befolkningsfremskrivning_tabel = befolkningsfremskrivning_T.reset_index()

# Vis datasættet
befolkningsfremskrivning_tabel.head(5)
# Out:
# Alder Årstal   0 år  1 år  2 år  3 år  4 år  5 år  6 år  Børn i alt
# 0       2020   9921  8590  8044  7307  6607  6148  5773       52390
# 1       2021   9892  8980  7863  7374  6878  6266  5872       53125
# 2       2022  10075  8949  8204  7215  6935  6522  5981       53881
# 3       2023  10282  9115  8175  7518  6791  6574  6227       54682
# 4       2024  10519  9299  8325  7489  7066  6440  6273       55411

# %% [markdown]
# ## Plot over befolkningsfremskrivning i KK 0-6 år

# %%
# For at gøre grafen mere overskuelig bruger vi kun data indtil år 2035
BF_35 = befolkningsfremskrivning_tabel.head(16)

# Plot over befolkningsfremskrivningen i Københavns Kommune for 0-6 årige børn
fig, ax = plt.subplots(figsize=(10, 5))
x3 = BF_35['Årstal']
y3 = BF_35['Børn i alt']
ax.scatter(x3, y3)
ax.plot(x3, y3)
ax.set(xlabel='Årstal', ylabel='Total antal børn 0-6 år i Københavns Kommune', title='Befolkningsfremskrivning af børn i Københavns Kommune 2020-2035')
# Out:
# [Text(0, 0.5, 'Total antal børn 0-6 år i Københavns Kommune'),
#  Text(0.5, 0, 'Årstal'),
#  Text(0.5, 1.0, 'Befolkningsfremskrivning af børn i Københavns Kommune 2020-2035')]

# %% [markdown]
# # For-loop der foreskriver udbud indtil 2030
# - I 2020 er udbuddet af pædagoger, pædagogmedhjælpere og -assistenter og dagplejere på 7352 - Tallet er fundet på Danmarks statistik 25/11-21
# - Man forventer at udbuddet af pædagoger vil stige med 2,6% om året

# %%
# Udregning af udbuddet af pædagoger fra 2021 til 2030

# Definerer startværdier
aar = 2020
udbud20 = 7352

dataUdbud = []

# Laver for-loop der tager udgangspunkt i 7352 pædagogisk personale i år 2020 og for hvert år lægger 2,6% oveni
# Data fra loop indsættes i dataFrame
for uddannedeP in range(10):
    uddannedeP = udbud20 * 1.026
    udbud20 = uddannedeP
    aar += 1
    dataUdbud.append({'Årstal': aar, 'Udbud': udbud20})
    dfUdbud1 = pd.DataFrame(dataUdbud)
    
# Inkluderer data fra 2020
dataUdbud20 = []
dataUdbud20.insert(0, {'Årstal': '2020', 'Udbud': 7352})

# Sætter data sammen fra loop og fra 2020 i en dataFrame
dfUdbud = pd.concat([pd.DataFrame(dataUdbud20), dfUdbud1], ignore_index=True)

# Viser tal i hele tal
dfUdbud['Udbud'] = dfUdbud['Udbud'].astype(int)

# Vis datasættet
dfUdbud
# Out:
#    Årstal  Udbud
# 0    2020   7352
# 1    2021   7543
# 2    2022   7739
# 3    2023   7940
# 4    2024   8146
# 5    2025   8358
# 6    2026   8576
# 7    2027   8799
# 8    2028   9027
# 9    2029   9262
# 10   2030   9503

# %% [markdown]
# ## Finder efterspørgsel af pædagoger fra 2020-2030

# %%
# Befolkningfremskrivningstabellen over børn i 0-5 års aldereren i Københavns Kommune giver os tallene
# Vi finder efterspørgslen i 2020 vha. disse tal og minimunsnummeringen på 1:6


b = np.array([52390, 53125, 53881, 54682, 55411, 56325, 57625, 58918, 60353, 61689, 62866])
aar2 = np.array([2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030])

# Dividerer med 6 så det passer med minimumsnormeringerne
eftersp = b/6

# Laver dataframe over efterspørgsel 
dfEftersp = pd.DataFrame()

dfEftersp['Årstal'] = aar2
dfEftersp['Efterspørgsel'] = eftersp

dfEftersp['Efterspørgsel'] = dfEftersp['Efterspørgsel'].astype(int)

# Vis datasættet
dfEftersp
# Out:
#     Årstal  Efterspørgsel
# 0     2020           8731
# 1     2021           8854
# 2     2022           8980
# 3     2023           9113
# 4     2024           9235
# 5     2025           9387
# 6     2026           9604
# 7     2027           9819
# 8     2028          10058
# 9     2029          10281
# 10    2030          10477

# %% [markdown]
# ## Hvor meget pædagigisk personale mangler hvert år

# %%
# Udregning af forskellen mellem udbud og efterspørgsel på pædagogisk personale

aar3 = ([2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030])
forskel = dfEftersp['Efterspørgsel'] - dfUdbud['Udbud']

dfForskel = pd.DataFrame()
dfForskel['Årstal'] = aar3
dfForskel['Forskel'] = forskel

# Vis datasættet
dfForskel
# Out:
#     Årstal  Forskel
# 0     2020     1379
# 1     2021     1311
# 2     2022     1241
# 3     2023     1173
# 4     2024     1089
# 5     2025     1029
# 6     2026     1028
# 7     2027     1020
# 8     2028     1031
# 9     2029     1019
# 10    2030      974

# %%
# merge bruges til at sammenflette fdUdbud, dfEftersp og dfForskel ud fra de kolonner de to tabeller deler

merge_UEF = pd.merge(pd.merge(dfUdbud, dfEftersp, on='Årstal'), dfForskel, on='Årstal')

# Vis datasættet
merge_UEF
# Out:
#   Årstal  Udbud  Efterspørgsel  Forskel
# 0   2021   7543           8854     1311
# 1   2022   7739           8980     1241
# 2   2023   7940           9113     1173
# 3   2024   8146           9235     1089
# 4   2025   8358           9387     1029
# 5   2026   8576           9604     1028
# 6   2027   8799           9819     1020
# 7   2028   9027          10058     1031
# 8   2029   9262          10281     1019
# 9   2030   9503          10477      974

# %% [markdown]
# ## Plot over udbud, efterspørgsel og forskel

# %%
# Definerer forskellige værdier
x = merge_UEF['Årstal']
y = merge_UEF['Udbud']
z = merge_UEF['Efterspørgsel']
a = merge_UEF['Forskel']

# Plot over udbud og efterspørgsel
fig, ax = plt.subplots(figsize=(10, 5))
plt.scatter(x, y, color='r')
plt.scatter(x, z, color='b')
lineU = plt.plot(x, y, color = 'r', label="Udbud")
lineE = plt.plot(x, z, color = 'b', label="Efterspørgsel")
plt.xlabel('Årstal'), plt.ylabel('Pædagogisk personale')
plt.title('Udvikling af udbud og efterspørgsel af pædagogisk personale frem til 2030')
plt.legend()

# Plot over forskellen i udbud og efterspørgsel
fig, ax = plt.subplots(figsize=(10, 5))
plt.scatter(x, a, color='g')
lineF = plt.plot(x, a, color = 'g', label="Forskel i udbud og efterspørgsel")
plt.xlabel('Årstal'), plt.ylabel('Pædagogisk personale')
plt.title('Udvikling af forskellen mellem udbud og efterspørgsel af pædagogisk personale frem til 2030')

plt.legend()
#plt.show()

# %% [markdown]
# # Pris for ønsket antal pædagogisk personale i 2022

# %%
# Finder forskellen mellem udbud og efterspørgsel af pædagogisk personale i 2022.
dfForskel['Forskel'][2]

# Regner 66% ud af 1241 manglende pædagogisk personale
stor_forskel = dfForskel['Forskel'][2]*0.66
stor_forskel

# Regner 34% ud af 1242 manglende pædagogisk personale
lille_forskel = dfForskel['Forskel'][2]-stor_forskel
lille_forskel

# Finder den samlede løn pr. år for en uddannet pædagog
loen_uddannet = loen['Pædagoger']['Samlet løn']*12
loen_uddannet

# Finder den samlede løn pr. år for ufaglært pædagog
loen_ikke_uddannet = loen['Ikke udd personale']['Samlet løn']*12
loen_ikke_uddannet

# Finder prisen for 66% uddannede pædagoger
pris_66_uddannede = int(stor_forskel*loen_uddannet)
pris_66_uddannede

#Finder prisen fra 34% ikke uddannede pædagoger.
pris_34_uddannede = int(lille_forskel*loen_ikke_uddannet)
pris_34_uddannede

i_alt = pris_66_uddannede+pris_34_uddannede

# Vis omkostning
i_alt

# Det vil koste KK 528.719.675,- om året, hvis 66% skal være uddannet pædagoger og 34% skal være ikke uddannet.
# Out:
# 528710675

# %%
# Tabel over de egentlige omkostninger ved at leve op til de to mål 
# sammenlignet med de penge der er afsat til det.

forskel3 = i_alt - 450000000

data1 = {'Årstal':[2022], 'Omkostninger': [i_alt], 'Rådighedsbeløb':[450000000], 'Mangler i kr.': [forskel3]}
omkost2 = pd.DataFrame(data = data1)

# Viser datasættet
omkost2
# Out:
#    Årstal  Omkostninger  Rådighedsbeløb  Mangler i kr.
# 0    2022     528710675       450000000       78710675

# %% [markdown]
# ## Omkostning ved kun at ansætte ufaglært til at opfylde minimumsnormeringerne

# %%
# Finder forskellen mellem udbud og efterspørgsel af pædagoger i 2022.
dfForskel['Forskel'][2]

#Den samlede løn for ikke uddannet personale på et år
loen_ikke_uddannet

# Pris for udelukkende at ansætte ikke uddannet personale for at nå minimumsnormering
pris_ikkeUdd = dfForskel['Forskel'][2]*loen_ikke_uddannet
pris_ikkeUdd
# Out:
# 489395796

# %%
# Laver en datasæt over omkostningerne for KUN at ansætte ufaglært personale
forskel2 = pris_ikkeUdd - 450000000

data = {'Årstal':[2022], 'Omkostninger': [pris_ikkeUdd], 'Rådighedsbeløb':[450000000], 'Mangler i kr.': [forskel2]}
omkost1 = pd.DataFrame(data = data)

# Viser datasættet
omkost1
# Out:
#    Årstal  Omkostninger  Rådighedsbeløb  Mangler i kr.
# 0    2022     489395796       450000000       39395796

# %% [markdown]
# # Mapping over institutioner og minimumnormeringer

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
import pandas as pd
from folium.plugins import MarkerCluster

# %%
# Laver et map over alle instirutioner i forhold til hvorvidt de opfylder minimumsnormeringer på 1:6
map = folium.Map(location=[55.675758, 12.569020], zoom_start=12, tiles="Stamen Terrain")

folium.Marker(
    location=[55.65870292280947, 12.60364145994735],
    popup="Solstrålen og Smørhullet",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.69349412277640, 12.559608539952723],
    popup="Børnehuset Urtehaven",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.66021961281015, 12.595556529948388],
    popup="Vuggestuen Sundholm",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.639039152835800, 12.605015899947217],
    popup="Ingolf",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.6654989427991, 12.606799479946917],
    popup="Børnehuset Lygtemagerstien",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.65084776282255, 12.596787299948254],
    popup="Kastanien",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.64242989282879, 12.612174939946268],
    popup="Idrætsinstitution Hoppeland",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.6678483628005, 12.593221239948665 ],
    popup="Den Grønne Planet",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.65414120280868, 12.623976189944647],
    popup="Børnehuset ved Volden",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.64711172282135, 12.61523435994585],
    popup="Børnenes Poppelhus",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.65788348281312, 12.596195449948311],
    popup="Skattekisten",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.63683306284468, 12.587839589949427],
    popup="Jorden Rundt",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.64273951283008, 12.607185699946925],
    popup="M-Husets Vuggestue",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.6594164128145, 12.585866819949615],
    popup="Sejlhuset",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.634463942849635, 12.582701859950074],
    popup="Børnehuset Gullfossgade",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.65350678280929, 12.624640179944558],
    popup="Viften",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.64756673281958, 12.61847880994541],
    popup="Østen for Solen",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.65601104281399, 12.601229429947667],
    popup="Snorretoppen",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.6635430628019, 12.606483209946962],
    popup="De 5 Årstider",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.7106060027593, 12.53960518995499],
    popup="Havblik",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.70933632276681, 12.520800629957074],
    popup="Paletten",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.70930551276808, 12.516793349957505],
    popup="Amagerhus",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.7078667727703, 12.515902429957602],
    popup="Børnehuset Gro",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.71587445274824, 12.551767469953587],
    popup="Gullandsgården",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.71129576275824, 12.539960199954955],
    popup="Hundredemeterskoven",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.68329278278778, 12.567744389951779],
    popup="Filosofvænget",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.683094532785965, 12.574187769951],
    popup="Solstrålen",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.67126756279676, 12.590479029949003],
    popup="Regnskoven",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.80405070262392, 12.561198599952268],
    popup="Enighedens Børnehus",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.85628175256146, 12.530258929955709],
    popup="Børnehuset Englegård",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.679050262790874, 12.576067279950783],
    popup="Klatretræet",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.6702391528013, 12.581003789950193],
    popup="Småbørnenes Forsamlingshus",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.69198262277253, 12.577960039950515],
    popup="Ørnen",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.69639775277413, 12.554361959953333],
    popup="Lundsgade",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.709916132755815, 12.553651639953385],
    popup="Kongehatten",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.695672732776764, 12.549208449953934],
    popup="Krudthuset",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.53030207309337, 12.176785999982592],
    popup="Vartov",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.70479122275389, 12.58130681995007],
    popup="Klerkegade",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.82343270259395, 12.571133299951024],
    popup="Titanrosen",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.64449192286203, 12.499289949959476],
    popup="Den Grønne Giraf",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.652839502842404, 12.526648969956565],
    popup="Cismofytten",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.6467373328692, 12.463695579962973],
    popup="Stenurten",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.49911707316622, 11.981650119989686],
    popup="Kastaniehuset - Vuggestue og Børnehave",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.6517597428477, 12.514086359957918],
    popup="Krible-Krable",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.59330529297385, 12.33998403997315],
    popup="7-Springeren",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.64618865287003, 12.463386569963001],
    popup="Murergården",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.662736972834765, 12.507080479958635],
    popup="Sølund",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.692769642798964, 12.489061079960415],
    popup="Valby Vuggestue",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.70864772278081, 12.476365649961636 ],
    popup="Labyrinten",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.71073585274803, 12.574259859950924],
    popup="Børnekompasset",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.69809580278654, 12.50638869995863],
    popup="Børnehuset Troldehøj",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.71042052278233, 12.462396439962971],
    popup="Børnehuset Savannen",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.65869666283488, 12.52510468995672],
    popup="Villa Valby",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.69764748278706, 12.506753699958592],
    popup="Børnehuset Fengersvej",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.697582472795354, 12.478659939961432],
    popup="Duetten",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.713804742771565, 12.483976429960878],
    popup="Vuggestuen Rugvej",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.774332762673126, 12.535018169955364],
    popup="Vindsuset",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.669637222811794, 12.551206529953765],
    popup="Tusindfryd",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.77552834270387, 12.421655999966518],
    popup="Drivhuset",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.6662465028164, 12.55124477995377],
    popup="Stjerneskuddet",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.66962446281133, 12.55267430995359],
    popup="Slottet",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)


folium.Marker(
    location=[55.672388422807565, 12.552664929953588],
    popup="Børnehuset ByToften",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.6484424228496, 12.522802499956994],
    popup="Lærkereden",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.66411100282259, 12.540897949954955],
    popup="Midtfløjene/Grostedet",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.668060, 12.552470],
    popup="Klatretræet på Vesterbro",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.69984468275925, 12.585553369949551],
    popup="BørnenesVerden",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.71374538274213, 12.579703559950248],
    popup="Barndommens Gade",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.70479206275143, 12.588692709949141],
    popup="Daginstitutionen Vesterbro Børneliv",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.700085582759804, 12.58284827994989],
    popup="Stubmøllen",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.70864225274675, 12.58689175994936],
    popup="Børnehuset Scandiagade",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.704422492754226, 12.581783419950012],
    popup="Vesterbro Børnegård",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.704442642754145, 12.581971099949987],
    popup="Idrætsinstitutionen Bavnehøj",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.701019722756136, 12.590057179948982],
    popup="Flora",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.71605254274418, 12.563660039952188],
    popup="Charlottehaven",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.715480, 12.565050],
    popup="Mælkebøtten",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.70413285275413, 12.583249289949832],
    popup="Villa Nova",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.71270933277433, 12.479537019961317],
    popup="Vokseværket",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.720442892761604, 12.48694718996057],
    popup="Vuggestuen Junglebo",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.710361622779196, 12.473834039961876],
    popup="Konkylien",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.676826762797674, 12.564490239952184],
    popup="Børnehusene ved Skoven",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.66515441282183, 12.538726689955197],
    popup="Rosenvang",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.69498913277743, 12.550070589953833],
    popup="Studsgården",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.686658752809294, 12.482259799961097],
    popup="Stjernen",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.69198262277253, 12.577960039950515],
    popup="Børnejunglen",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.69500368278589, 12.522659559956898],
    popup="Børnehuset Støberigade",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.655687902850225, 12.48725030996067],
    popup="Forfatterhuset",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.667994042825796, 12.513054989957991],
    popup="Børnehuset Vesterbro",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.86316582255901, 12.506755639958234],
    popup="Damperen",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.72406298273279, 12.564926219952019],
    popup="Hulahophuset",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.64783348284658, 12.535276399955622],
    popup="Børnehuset Tusindfryd",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.667800022797884, 12.601141989947644],
    popup="Humlehuset",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.652190, 12.532400],
    popup="Børnegården Frederiksholm",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.66553687282417, 12.529564239956214],
    popup="Børnehuset Håbets Allé - Børnehave",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.77433276267312, 12.535018169955364],
    popup="Grøndalen",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.667994042825796, 12.513054989957991],
    popup="Isbjørnen",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.619818852873806, 12.570047169951662],
    popup="Børnehuset Jorn",
    icon=folium.Icon(color="orange", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.70191385276709, 12.55272761995351],
    popup="Olympia",
    icon=folium.Icon(color="green", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.643193, 12.508651],
    popup="Lyngholmen",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

folium.Marker(
    location=[55.664760, 12.595950],
    popup="Børnehuset i Svinget",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Barplot over tilsynsrapporter

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()

# %%
# Laver dataframe over gule og røde institutioner i procent
rapporter = {
    '2017': [51],
    '2018': [47],
    '2019': [40],
    '2020': [33],
}

df_rap = pd.DataFrame(rapporter)

df_rap.index = ['Gule- og røde institutioner i pct']

# Viser datasættet
df_rap
# Out:
#                                    2017  2018  2019  2020
# Gule- og røde institutioner i pct    51    47    40    33

# %%
# Definerer parametre for barplot
objects = ('2017', '2018', '2019', '2020')
y_pos = np.arange(len(objects))
rapporter = [51, 47, 40, 33]

plt.bar(y_pos, rapporter, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Pct. af inst. som er gule eller røde')
plt.title('Tilsynsrapporter')

# Viser barplottet
plt.show()

# %% [markdown]
# # Histogram over andelen af pædagogisk personale der er faglært

# %%
import statistics
import warnings
warnings.filterwarnings('ignore')

# %%
# Indlæser datasæt over institutioner i Københavns Kommune
dfInst = pd.read_csv('inst2.csv', sep = ',')

# Vis datasæt
dfInst
# Out:
#      KKorgnr            Institution_Navn  \
# 0     1639.0    Solstrålen og Smørhullet
# 1     1640.0        Børnehuset Urtehaven
# 2     1643.0         Vuggestuen Sundholm
# 3     1644.0                      Ingolf
# 4     1645.0  Børnehuset Lygtemagerstien
# ..       ...                         ...
# 209      NaN                         NaN
# 210      NaN                         NaN
# 211      NaN                         NaN
# 212      NaN                         NaN
# 213      NaN                         NaN
#
#     Andel af pæd personale, der er uddannet 2020 Antal uddannede pædagoger  \
# 0                                            64%                        11
# 1                                            61%                       NaN
# 2                                            41%                       NaN
# 3                                            54%                         6
# 4                                            58%                        10
# ...

# %%
# Dropper række 206-213 da de ikke indeholder data
dfInst = dfInst.drop([206, 207, 208,209, 210, 211, 212, 213])
dfInst
# Out:
#      KKorgnr            Institution_Navn  \
# 0     1639.0    Solstrålen og Smørhullet
# 1     1640.0        Børnehuset Urtehaven
# 2     1643.0         Vuggestuen Sundholm
# 3     1644.0                      Ingolf
# 4     1645.0  Børnehuset Lygtemagerstien
# ..       ...                         ...
# 201   6182.0     Børnehuset Den Gule Hat
# 202   6263.0              Enghave Remise
# 203   6290.0                  Lyngholmen
# 204   6374.0        Børnehuset i Svinget
# 205   6375.0            Børnehuset Bella
#
#     Andel af pæd personale, der er uddannet 2020 Antal uddannede pædagoger  \
# 0                                            64%                        11
# 1                                            61%                       NaN
# 2                                            41%                       NaN
# 3                                            54%                         6
# 4                                            58%                        10
# ...

# %%
# Ændrer navnet på nogle af kolonnerne
dfInst.rename(columns = {'Andel af pæd personale, der er uddannet 2020' : 'paedpct', 'Børn pr. voksen (rundet op)' : 'Normering'}, inplace = True)
dfInst
# Out:
#      KKorgnr            Institution_Navn paedpct Antal uddannede pædagoger  \
# 0     1639.0    Solstrålen og Smørhullet     64%                        11
# 1     1640.0        Børnehuset Urtehaven     61%                       NaN
# 2     1643.0         Vuggestuen Sundholm     41%                       NaN
# 3     1644.0                      Ingolf     54%                         6
# 4     1645.0  Børnehuset Lygtemagerstien     58%                        10
# ..       ...                         ...     ...                       ...
# 201   6182.0     Børnehuset Den Gule Hat     62%                       NaN
# 202   6263.0              Enghave Remise     59%                       NaN
# 203   6290.0                  Lyngholmen     22%                         5
# 204   6374.0        Børnehuset i Svinget     55%                       NaN
# 205   6375.0            Børnehuset Bella     64%                       NaN
#
#      Antal pædagogmedhjælpere (inkl. assistenter)  \
# ...

# %%
print(dfInst['paedpct'])
print(type('paedpct'))
# Out:
# 0      64%
# 1      61%
# 2      41%
# 3      54%
# 4      58%
#       ...
# 201    62%
# 202    59%
# 203    22%
# 204    55%
# 205    64%
# Name: paedpct, Length: 206, dtype: object
# <class 'str'>

# %%
#laver string-procenter om til integers, så vi kan bruge dem
dfInst['paedpct'] = dfInst['paedpct'].str.rstrip('%').astype('int')

# Vis datasæt
dfInst
# Out:
#      KKorgnr            Institution_Navn  paedpct Antal uddannede pædagoger  \
# 0     1639.0    Solstrålen og Smørhullet       64                        11
# 1     1640.0        Børnehuset Urtehaven       61                       NaN
# 2     1643.0         Vuggestuen Sundholm       41                       NaN
# 3     1644.0                      Ingolf       54                         6
# 4     1645.0  Børnehuset Lygtemagerstien       58                        10
# ..       ...                         ...      ...                       ...
# 201   6182.0     Børnehuset Den Gule Hat       62                       NaN
# 202   6263.0              Enghave Remise       59                       NaN
# 203   6290.0                  Lyngholmen       22                         5
# 204   6374.0        Børnehuset i Svinget       55                       NaN
# 205   6375.0            Børnehuset Bella       64                       NaN
#
#      Antal pædagogmedhjælpere (inkl. assistenter)  \
# ...

# %%
ppct = dfInst['paedpct']

#Laver histogram over anddelen af pædagoger i institutionerne 
fig, ax = plt.subplots(figsize = (20, 10))
ax.set_title('Institutioners andel af pædagogisk personale som er faglærte', fontsize = 25)
ax = sns.distplot(ppct,hist=True)
plt.xlabel('Procentdel af inst. som er udd. pædagoger', fontsize=20)
plt.ylabel('Density', fontsize=20)
sns.despine()
plt.axvline(x=66, ymin=0, ymax=1, color = 'red', label = 'målsætning')
plt.text(67.1,0.04,'målsætning',rotation=0)
# Out:
# Text(67.1, 0.04, 'målsætning')

# %%
# Finder gennemsnittet af hvor stor en andel af det pædagogiske personale der er faglærte
paedpct = dfInst['paedpct']
statistics.mean(paedpct)
# Out:
# 55.71844660194175
