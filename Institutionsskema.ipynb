# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Vi henter data og opretter dataframe med titlen 'df'. Dette er vores rå data, som giver et overblik over alle observationer og tilhørende informationer.
#
# #### 'KKorgnr', 'Institution_Navn' og 'Koordinater' er hentet fra offentligt tilgængelige data om daginstitutioner i Københavns Kommune
#
# #### 'Antal uddannede pædagoger', 'Antal pædagogmedhjælpere' 'Andre midlertidigt tilknyttede' og 'antal børn' er manuelt tilføjet med information hentet fra nettet. Kilderne til informationer om disse variable varierer, og fremgår derfor af variablen 'kilde' i hver enkelt observation. Variablen 'Samlede pædagoger' er defineret ved summen af 'antal uddannede pædagoger' og 'antal pædagogmedhjælpere', og variablen 'børn pr. voksen' er defineret ved at dividere 'antal børn' med 'samlede pædagoger', hvorefter vi runder op til næste hele tal
#
# #### 'Andel af pæd. personale, der er uddannet 2020' er hentet fra det aktindsigt, vi modtog fra Københavns Kommune.

# %%
pd.read_csv('inst2.csv', sep = ',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cbf3bd44a41d> in <module>
# ----> 1 pd.read_csv('inst2.csv', sep = ',')
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv('inst2.csv', sep = ',')

# %%
#df = df.drop([206, 207, 208, 209, 210, 211, 212, 213])
df
# Out:
#      KKorgnr            Institution_Navn  \
# 0     1639.0    Solstrålen og Smørhullet
# 1     1640.0        Børnehuset Urtehaven
# 2     1643.0         Vuggestuen Sundholm
# 3     1644.0                      Ingolf
# 4     1645.0  Børnehuset Lygtemagerstien
# ..       ...                         ...
# 201   6182.0     Børnehuset Den Gule Hat
# 202   6263.0              Enghave Remise
# 203   6290.0                  Lyngholmen
# 204   6374.0        Børnehuset i Svinget
# 205   6375.0            Børnehuset Bella
#
#     Andel af pæd personale, der er uddannet 2020 Antal uddannede pædagoger  \
# 0                                            64%                        11
# 1                                            61%                       NaN
# 2                                            41%                       NaN
# 3                                            54%                         6
# 4                                            58%                        10
# ...

# %%
#ændrer navnet på andelen af pæd. personale..
df.rename(columns = {'Andel af pæd personale, der er uddannet 2020' : 'paedpct', 'Børn pr. voksen (rundet op)' : 'Normering'}, inplace = True)
df
# Out:
#      KKorgnr            Institution_Navn paedpct Antal uddannede pædagoger  \
# 0     1639.0    Solstrålen og Smørhullet     64%                        11
# 1     1640.0        Børnehuset Urtehaven     61%                       NaN
# 2     1643.0         Vuggestuen Sundholm     41%                       NaN
# 3     1644.0                      Ingolf     54%                         6
# 4     1645.0  Børnehuset Lygtemagerstien     58%                        10
# ..       ...                         ...     ...                       ...
# 201   6182.0     Børnehuset Den Gule Hat     62%                       NaN
# 202   6263.0              Enghave Remise     59%                       NaN
# 203   6290.0                  Lyngholmen     22%                         5
# 204   6374.0        Børnehuset i Svinget     55%                       NaN
# 205   6375.0            Børnehuset Bella     64%                       NaN
#
#      Antal pædagogmedhjælpere (inkl. assistenter)  \
# ...

# %%
#jeg dropper de observationer, som ikke har nogen normering, dvs. som vi ikke har data på
df = df.dropna(subset = ['Normering'])

df
# Out:
#      KKorgnr            Institution_Navn paedpct Antal uddannede pædagoger  \
# 0     1639.0    Solstrålen og Smørhullet     64%                        11
# 1     1640.0        Børnehuset Urtehaven     61%                       NaN
# 2     1643.0         Vuggestuen Sundholm     41%                       NaN
# 3     1644.0                      Ingolf     54%                         6
# 4     1645.0  Børnehuset Lygtemagerstien     58%                        10
# ..       ...                         ...     ...                       ...
# 195   6018.0                  Æblekassen     37%                       NaN
# 199   6034.0                     Olympia     60%                         7
# 202   6263.0              Enghave Remise     59%                       NaN
# 203   6290.0                  Lyngholmen     22%                         5
# 204   6374.0        Børnehuset i Svinget     55%                       NaN
#
#      Antal pædagogmedhjælpere (inkl. assistenter)  \
# ...

# %%
print(type('paedpct'))
# Out:
# <class 'str'>

# %%
print(df['paedpct'])
# Out:
# 0      64%
# 1      61%
# 2      41%
# 3      54%
# 4      58%
#       ...
# 195    37%
# 199    60%
# 202    59%
# 203    22%
# 204    55%
# Name: paedpct, Length: 119, dtype: object

# %%
#laver string-procenter om til integers, så vi kan bruge dem
df['paedpct'] = df['paedpct'].str.rstrip('%').astype('string')
df
# Out:
#      KKorgnr            Institution_Navn paedpct Antal uddannede pædagoger  \
# 0     1639.0    Solstrålen og Smørhullet      64                        11
# 1     1640.0        Børnehuset Urtehaven      61                       NaN
# 2     1643.0         Vuggestuen Sundholm      41                       NaN
# 3     1644.0                      Ingolf      54                         6
# 4     1645.0  Børnehuset Lygtemagerstien      58                        10
# ..       ...                         ...     ...                       ...
# 195   6018.0                  Æblekassen      37                       NaN
# 199   6034.0                     Olympia      60                         7
# 202   6263.0              Enghave Remise      59                       NaN
# 203   6290.0                  Lyngholmen      22                         5
# 204   6374.0        Børnehuset i Svinget      55                       NaN
#
#      Antal pædagogmedhjælpere (inkl. assistenter)  \
# ...

# %%
#jeg inspicerer variablen 'Normering'
df['Normering'].value_counts()
# Out:
# 6.0     41
# 5.0     25
# 4.0     19
# 7.0     12
# 8.0     10
# 9.0      6
# 3.0      4
# 13.0     1
# 2.0      1
# Name: Normering, dtype: int64

# %%
#jeg finder gennemsnittet for Normering
df['Normering'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-69cc763e648a> in <module>
# ----> 1 df['Normering'].mean()
#
# NameError: name 'df' is not defined
